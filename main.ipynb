# %% [markdown]
# # 初期設定

# %% [markdown]
# Googleマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# データセットのダウンロード

# %%
# !unzip /content/drive/MyDrive/yfujiwara/datasets/yelp2018.zip
# Out:
# Archive:  /content/drive/MyDrive/yfujiwara/datasets/yelp2018.zip
#   inflating: user_list.txt
#   inflating: entity_list.txt
#   inflating: item_list.txt
#   inflating: kg_final.txt
#   inflating: README.md
#   inflating: relation_list.txt
#   inflating: test.txt
#   inflating: train.txt

# %% [markdown]
# Githubからコードをダウンロード

# %%
# !git clone https://github.com/youfuji/AKDN_python.git
# Out:
# Cloning into 'AKDN_python'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 47 (delta 17), reused 42 (delta 14), pack-reused 0 (from 0)
# Receiving objects: 100% (47/47), 13.21 KiB | 4.40 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
# %cd AKDN_python
# Out:
# /content/AKDN_python

# %% [markdown]
# GPUの確認

# %%
import torch
torch.cuda.is_available()
# Out:
# True
